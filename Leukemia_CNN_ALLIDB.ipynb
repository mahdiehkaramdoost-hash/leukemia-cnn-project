# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow opencv-python matplotlib scikit-learn

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE = 224
BATCH_SIZE = 32

train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = train_datagen.flow_from_directory(
    '/content/dataset',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    '/content/dataset',
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='binary',
    subset='validation'
)

model = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128,activation='relu'),
    Dropout(0.5),

    Dense(1,activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_9505/829476687.py in <cell line: 0>()
#      16 )
#      17
# ---> 18 train_generator = train_datagen.flow_from_directory(
#      19     '/content/dataset',
#      20     target_size=(IMG_SIZE, IMG_SIZE),
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1134         keep_aspect_ratio=False,
#    1135     ):
# -> 1136         return DirectoryIterator(
#    1137             directory,
#    1138             self,
#
# ...

# %%
# !ls /content
# Out:
# drive  sample_data

# %%
# !find /content/drive -type f | grep -E "jpg|png|jpeg" | head -20
# Out:
# /content/drive/MyDrive/ALLIDB/L1/Im076_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im073_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im075_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im067_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im066_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im069_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im074_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im071_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im0671_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im064_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im070_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im065_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im068_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im072_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im086_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im087_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im078_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im088_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im077_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im079_0.jpg

# %%
# !find /content/drive -name "*.zip"

# %%
import os

path = "/content/drive/MyDrive/ALLIDB/L1"

print("Number of files:", len(os.listdir(path)))

print(os.listdir(path)[:20])

# %%
# !find /content/drive/MyDrive/ALLIDB -maxdepth 2 -type d
# Out:
# find: ‘/content/drive/MyDrive/ALLIDB’: No such file or directory

# %%
# !ls "/content/drive/MyDrive"
# Out:
# ls: cannot access '/content/drive/MyDrive': No such file or directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive
# Out:
# MyDrive

# %%
# !ls /content/drive/MyDrive
# Out:
#  ALLIDB  'Colab Notebooks'

# %%
# !find /content/drive/MyDrive/ALLIDB -maxdepth 2 -type d
# Out:
# /content/drive/MyDrive/ALLIDB
# /content/drive/MyDrive/ALLIDB/L1
# /content/drive/MyDrive/ALLIDB/L2
# /content/drive/MyDrive/ALLIDB/L3

# %%
# !ls /content/drive/MyDrive/ALLIDB/L1 | head -20
# !ls /content/drive/MyDrive/ALLIDB/L2 | head -20
# !ls /content/drive/MyDrive/ALLIDB/L3 | head -20
# Out:
# Im064_0.jpg
# Im065_0.jpg
# Im066_0.jpg
# Im067_0.jpg
# Im0671_0.jpg
# Im068_0.jpg
# Im069_0.jpg
# Im070_0.jpg
# Im071_0.jpg
# Im072_0.jpg
# Im073_0.jpg
# Im074_0.jpg
# Im075_0.jpg
# Im076_0.jpg
# Im077_0.jpg
# Im078_0.jpg
# Im078_3.jpg
# Im0788_0.jpg
# Im079_0.jpg
# Im080_0.jpg
# Im0011_1.jpg
# Im001_1.jpg
# Im003_10.jpg
# Im003_11.jpg
# Im0031_1.jpg
# Im003_12.jpg
# Im003_13.jpg
# Im003_14.jpg
# Im003_15.jpg
# Im003_16.jpg
# Im003_1.jpg
# Im003_2.jpg
# Im003_3.jpg
# Im003_4.jpg
# Im003_5.jpg
# Im003_6.jpg
# Im003_7.jpg
# Im003_8.jpg
# Im003_9.jpg
# Im004_1.jpg
# Im001_1.tif
# Im002_1.tif
# Im003_10.jpg
# Im003_11.jpg
# Im003_12.jpg
# Im003_13.jpg
# Im003_14.jpg
# Im003_15.jpg
# Im003_16.jpg
# Im003_17.jpg
# Im003_18.jpg
# Im003_1.tif
# Im003_21.jpg
# Im003_22.jpg
# Im003_23.jpg
# Im003_24.jpg
# Im003_26.jpg
# Im003_28.jpg
# Im003_29.jpg
# Im003_30.jpg

# %%
# !ls /content/drive/MyDrive/ALLIDB/L2 | head -20
# Out:
# Im0011_1.jpg
# Im001_1.jpg
# Im003_10.jpg
# Im003_11.jpg
# Im0031_1.jpg
# Im003_12.jpg
# Im003_13.jpg
# Im003_14.jpg
# Im003_15.jpg
# Im003_16.jpg
# Im003_1.jpg
# Im003_2.jpg
# Im003_3.jpg
# Im003_4.jpg
# Im003_5.jpg
# Im003_6.jpg
# Im003_7.jpg
# Im003_8.jpg
# Im003_9.jpg
# Im004_1.jpg

# %%
import os

for folder in ["L1","L2","L3"]:
    path = f"/content/drive/MyDrive/ALLIDB/{folder}"
    print(folder, "=>", len(os.listdir(path)))
# Out:
# L1 => 50
# L2 => 50
# L3 => 50

# %%
# !find /content/drive/MyDrive/ALLIDB -type f | grep -i "xls\|csv\|txt"

# %%
# !find /content/drive/MyDrive/ALLIDB -type f | sort | head -100
# Out:
# /content/drive/MyDrive/ALLIDB/L1/Im064_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im065_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im066_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im067_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im0671_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im068_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im069_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im070_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im071_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im072_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im073_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im074_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im075_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im076_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im077_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im078_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im078_3.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im0788_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im079_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im080_0.jpg
# /content/drive/MyDrive/ALLIDB/L1/Im0801_0.jpg
# ...

# %%
import os

path = "/content/drive/MyDrive/ALLIDB/L3"

files = [f for f in os.listdir(path) if f.endswith((".jpg",".jpeg",".tif"))]

print("Total files:", len(files))
print(files[:20])
# Out:
# Total files: 50
# ['Im001_1.tif', 'Im002_1.tif', 'Im003_1.tif', 'Im013_1.tif', 'Im003_32.jpg', 'Im003_29.jpg', 'Im003_48.jpg', 'Im003_36.jpg', 'Im012_1.tif', 'Im003_47.jpg', 'Im004_1.tif', 'Im003_16.jpg', 'Im003_21.jpg', 'Im003_14.jpg', 'Im003_42.jpg', 'Im009_1.tif', 'Im003_13.jpg', 'Im003_50.jpg', 'Im011_1.tif', 'Im003_45.jpg']

# %%
import os

path = "/content/drive/MyDrive/ALLIDB/L3"

healthy = 0
leukemia = 0

for f in os.listdir(path):
    if "_0" in f:
        healthy += 1
    elif "_1" in f:
        leukemia += 1

print("Healthy:", healthy)
print("Leukemia:", leukemia)
# Out:
# Healthy: 0
# Leukemia: 21

# %%
import os

path = "/content/drive/MyDrive/ALLIDB/L3"

files = sorted(os.listdir(path))

print("Number of files:", len(files))

for f in files[:50]:
    print(f)
# Out:
# Number of files: 50
# Im001_1.tif
# Im002_1.tif
# Im003_1.tif
# Im003_10.jpg
# Im003_11.jpg
# Im003_12.jpg
# Im003_13.jpg
# Im003_14.jpg
# Im003_15.jpg
# Im003_16.jpg
# Im003_17.jpg
# Im003_18.jpg
# Im003_21.jpg
# Im003_22.jpg
# Im003_23.jpg
# Im003_24.jpg
# Im003_26.jpg
# Im003_28.jpg
# Im003_29.jpg
# Im003_30.jpg
# Im003_31.jpg
# Im003_32.jpg
# Im003_33.jpg
# Im003_34.jpg
# Im003_35.jpg
# Im003_36.jpg
# Im003_37.jpg
# Im003_38.jpg
# Im003_39.jpg
# Im003_40.jpg
# Im003_41.jpg
# Im003_42.jpg
# Im003_43.jpg
# Im003_44.jpg
# Im003_45.jpg
# Im003_46.jpg
# Im003_47.jpg
# Im003_48.jpg
# Im003_49.jpg
# Im003_50.jpg
# Im003_52.jpg
# Im004_1.tif
# Im005_1.tif
# Im006_1.tif
# Im008_1.tif
# Im009_1.tif
# Im010_1.tif
# Im011_1.tif
# Im012_1.tif
# Im013_1.tif

# %%
# !ls /content/drive/MyDrive/ALLIDB/L3 | tail -30
# Out:
# Im003_31.jpg
# Im003_32.jpg
# Im003_33.jpg
# Im003_34.jpg
# Im003_35.jpg
# Im003_36.jpg
# Im003_37.jpg
# Im003_38.jpg
# Im003_39.jpg
# Im003_40.jpg
# Im003_41.jpg
# Im003_42.jpg
# Im003_43.jpg
# Im003_44.jpg
# Im003_45.jpg
# Im003_46.jpg
# Im003_47.jpg
# Im003_48.jpg
# Im003_49.jpg
# Im003_50.jpg
# Im003_52.jpg
# Im004_1.tif
# Im005_1.tif
# Im006_1.tif
# Im008_1.tif
# Im009_1.tif
# Im010_1.tif
# Im011_1.tif
# Im012_1.tif
# Im013_1.tif

# %%
# !ls -R /content/drive/MyDrive/ALLIDB
# Out:
# /content/drive/MyDrive/ALLIDB:
# L1  L2	L3
#
# /content/drive/MyDrive/ALLIDB/L1:
# Im064_0.jpg   Im073_0.jpg   Im0801_0.jpg  Im088_0.jpg	Im101_0.jpg
# Im065_0.jpg   Im074_0.jpg   Im081_0.jpg   Im089_0.jpg	Im102_0.jpg
# Im066_0.jpg   Im075_0.jpg   Im0811_0.jpg  Im090_0.jpg	Im1021_0.jpg
# Im067_0.jpg   Im076_0.jpg   Im082_0.jpg   Im091_0.jpg	Im103_0.jpg
# Im0671_0.jpg  Im077_0.jpg   Im083_0.jpg   Im092_0.jpg	Im104_0.jpg
# Im068_0.jpg   Im078_0.jpg   Im084_0.jpg   Im0921_0.jpg	Im105_0.jpg
# Im069_0.jpg   Im078_3.jpg   Im085_0.jpg   Im093_0.jpg	Im106_0.jpg
# Im070_0.jpg   Im0788_0.jpg  Im086_02.jpg  Im098_0.jpg	Im107_0.jpg
# Im071_0.jpg   Im079_0.jpg   Im086_0.jpg   Im099_0.jpg	Im107_3.jpg
# Im072_0.jpg   Im080_0.jpg   Im087_0.jpg   Im100_0.jpg	Im108_0.jpg
#
# /content/drive/MyDrive/ALLIDB/L2:
# Im0011_1.jpg  Im003_1.jpg  Im009_1.jpg	Im019_1.jpg   Im025_1.jpg
# Im001_1.jpg   Im003_2.jpg  Im010_1.jpg	Im020_1.jpg   Im026_1.jpg
# ...

# %%
import os, shutil

base = "/content/dataset"

os.makedirs(base+"/Healthy", exist_ok=True)
os.makedirs(base+"/Leukemia", exist_ok=True)

for f in os.listdir("/content/drive/MyDrive/ALLIDB/L1"):
    shutil.copy(
        f"/content/drive/MyDrive/ALLIDB/L1/{f}",
        f"{base}/Healthy/{f}"
    )

for f in os.listdir("/content/drive/MyDrive/ALLIDB/L2"):
    shutil.copy(
        f"/content/drive/MyDrive/ALLIDB/L2/{f}",
        f"{base}/Leukemia/{f}"
    )

print("Dataset Ready")
# Out:
# Dataset Ready

# %%
import os

print("Healthy =", len(os.listdir("/content/dataset/Healthy")))
print("Leukemia =", len(os.listdir("/content/dataset/Leukemia")))
# Out:
# Healthy = 50
# Leukemia = 50

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

IMG_SIZE = 224
BATCH_SIZE = 16

datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=20,
    zoom_range=0.2,
    horizontal_flip=True
)

train_generator = datagen.flow_from_directory(
    "/content/dataset",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="training"
)

val_generator = datagen.flow_from_directory(
    "/content/dataset",
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode="binary",
    subset="validation"
)

model = Sequential([
    Conv2D(32,(3,3),activation='relu',input_shape=(224,224,3)),
    MaxPooling2D(2,2),

    Conv2D(64,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Conv2D(128,(3,3),activation='relu'),
    MaxPooling2D(2,2),

    Flatten(),

    Dense(128,activation='relu'),
    Dropout(0.5),

    Dense(1,activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=20
)
# Out:
# Found 80 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.4500 - loss: 2.4104 - val_accuracy: 0.5000 - val_loss: 0.7254
# Epoch 2/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.5000 - loss: 0.7198 - val_accuracy: 0.5000 - val_loss: 0.6837
# Epoch 3/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 10s 1s/step - accuracy: 0.5750 - loss: 0.7079 - val_accuracy: 0.5000 - val_loss: 0.7748
# Epoch 4/20
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.4625 - loss: 0.7415 - val_accuracy: 0.5000 - val_loss: 0.6684
# Epoch 5/20
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train','Validation'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Validation'])
plt.show()

# %%
from sklearn.metrics import classification_report
import numpy as np

val_generator.reset()

pred = model.predict(val_generator)
pred = (pred > 0.5).astype(int)

print(classification_report(
    val_generator.classes,
    pred[:len(val_generator.classes)]
))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step
#               precision    recall  f1-score   support
#
#            0       0.40      0.40      0.40        10
#            1       0.40      0.40      0.40        10
#
#     accuracy                           0.40        20
#    macro avg       0.40      0.40      0.40        20
# weighted avg       0.40      0.40      0.40        20

# %%
print("Final Train Accuracy =", history.history['accuracy'][-1])
print("Final Validation Accuracy =", history.history['val_accuracy'][-1])
# Out:
# Final Train Accuracy = 0.925000011920929
# Final Validation Accuracy = 0.949999988079071

# %%
from sklearn.metrics import classification_report, confusion_matrix
import numpy as np

val_generator.reset()

pred_prob = model.predict(val_generator, verbose=1)
pred = (pred_prob > 0.5).astype(int).flatten()

true_labels = val_generator.classes

print(confusion_matrix(true_labels, pred))
print(classification_report(true_labels, pred))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step
# [[3 7]
#  [7 3]]
#               precision    recall  f1-score   support
#
#            0       0.30      0.30      0.30        10
#            1       0.30      0.30      0.30        10
#
#     accuracy                           0.30        20
#    macro avg       0.30      0.30      0.30        20
# weighted avg       0.30      0.30      0.30        20

# %%
import matplotlib.pyplot as plt
import cv2

img = cv2.imread('/content/drive/MyDrive/ALLIDB/L1/Im064_0.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

img = cv2.imread('/content/drive/MyDrive/ALLIDB/L2/Im001_1.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
epochs=30

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=30,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 17s 4s/step - accuracy: 0.9875 - loss: 0.0937 - val_accuracy: 0.9500 - val_loss: 0.0845
# Epoch 2/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 12s 2s/step - accuracy: 0.9875 - loss: 0.0471 - val_accuracy: 1.0000 - val_loss: 0.0307
# Epoch 3/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 0.0092 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 4/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 1.0000 - loss: 0.0056 - val_accuracy: 1.0000 - val_loss: 8.6696e-04
# Epoch 5/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.9875 - loss: 0.0240 - val_accuracy: 1.0000 - val_loss: 0.0115
# Epoch 6/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step - accuracy: 1.0000 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 7/30
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 1.0000 - loss: 0.0113 - val_accuracy: 1.0000 - val_loss: 5.0117e-04
# Epoch 8/30
# ...

# %%
print("Best Validation Accuracy =", max(history.history['val_accuracy']))
print("Best Validation Loss =", min(history.history['val_loss']))
# Out:
# Best Validation Accuracy = 1.0
# Best Validation Loss = 0.0004797312431037426

# %%
print("Final Train Accuracy =", history.history['accuracy'][-1])
print("Final Validation Accuracy =", history.history['val_accuracy'][-1])
# Out:
# Final Train Accuracy = 1.0
# Final Validation Accuracy = 1.0
